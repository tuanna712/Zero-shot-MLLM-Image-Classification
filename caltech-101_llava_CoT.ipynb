# %%
import numpy as np
import pandas as pd
import json, os, time, pickle
from modules.llm import LlavaModel, LlamaModel
from modules.prompts import CoTPrompt
from dotenv import load_dotenv; load_dotenv()

CoT = CoTPrompt("CoT")

caltech_images_path = '../database/Caltech/'
caltech_class_meta_path = '../data/caltech-101/meta/caltech_220_images.json'

REPLICATE_API_TOKEN = os.getenv("REPLICATE_API_TOKEN")
LLaVA = LlavaModel(REPLICATE_API_TOKEN)
Llama = LlamaModel(REPLICATE_API_TOKEN)

# %% [markdown]
# ### LLM Calls for Generating Addition Information

# %%
from modules.gen_features import ImageFeatures
caltech_image_working_file = "../data/caltech-101/cotPrompt/llava/image_features.parquet"
Cal101Features = ImageFeatures(caltech_images_path, caltech_class_meta_path, 
                             caltech_image_working_file, llm_model=LLaVA, PromptSys=CoT)
Cal101Features.gen_info()
# Out:
# Loaded parquet!
# Loaded parquet!
# 1/202
# gerenuk_0011 done!
# 2/202
# Image: gerenuk_0010
# Time taken per label: 21.26 seconds
# --------------------------------------------------
# 3/202
# Image: hawksbill_0085
# Time taken per label: 20.03 seconds
# --------------------------------------------------
# 4/202
# Image: hawksbill_0017
# Time taken per label: 18.75 seconds
# --------------------------------------------------
# 5/202
# Image: headphone_0024
# Time taken per label: 18.34 seconds
# --------------------------------------------------
# 6/202
# Image: headphone_0004
# Time taken per label: 22.71 seconds
# --------------------------------------------------
# 7/202
# Image: ant_0011
# Time taken per label: 21.39 seconds
# --------------------------------------------------
# 8/202
# Image: ant_0037
# Time taken per label: 24.06 seconds
# --------------------------------------------------
# 9/202
# Image: butterfly_0089
# Time taken per label: 19.24 seconds
# --------------------------------------------------
# 10/202
# Image: butterfly_0038
# Time taken per label: 18.4 seconds
# --------------------------------------------------
# 11/202
# Image: lamp_0033
# Time taken per label: 19.8 seconds
# --------------------------------------------------
# 12/202
# Image: lamp_0030
# Time taken per label: 20.52 seconds
# --------------------------------------------------
# 13/202
# Image: strawberry_0026
# Time taken per label: 19.08 seconds
# --------------------------------------------------
# 14/202
# Image: strawberry_0004
# Time taken per label: 20.01 seconds
# --------------------------------------------------
# 15/202
# Image: water_lilly_0033
# Time taken per label: 20.56 seconds
# --------------------------------------------------
# 16/202
# Image: water_lilly_0012
# Time taken per label: 20.97 seconds
# --------------------------------------------------
# 17/202
# Image: chandelier_0016
# Time taken per label: 19.44 seconds
# --------------------------------------------------
# 18/202
# Image: chandelier_0077
# Time taken per label: 23.83 seconds
# --------------------------------------------------
# 19/202
# Image: dragonfly_0051
# Time taken per label: 25.21 seconds
# --------------------------------------------------
# 20/202
# Image: dragonfly_0039
# Time taken per label: 19.44 seconds
# --------------------------------------------------
# 21/202
# Image: crab_0020
# Time taken per label: 18.99 seconds
# --------------------------------------------------
# 22/202
# Image: crab_0038
# Time taken per label: 28.11 seconds
# --------------------------------------------------
# 23/202
# Image: pagoda_0035
# Time taken per label: 24.45 seconds
# --------------------------------------------------
# 24/202
# Image: pagoda_0039
# Time taken per label: 19.86 seconds
# --------------------------------------------------
# 25/202
# Image: dollar_bill_0034
# Time taken per label: 18.95 seconds
# --------------------------------------------------
# 26/202
# Image: dollar_bill_0032
# Time taken per label: 22.84 seconds
# --------------------------------------------------
# 27/202
# Image: emu_0010
# Time taken per label: 25.2 seconds
# --------------------------------------------------
# 28/202
# Image: emu_0011
# Time taken per label: 26.92 seconds
# --------------------------------------------------
# 29/202
# Image: inline_skate_0016
# Time taken per label: 36.06 seconds
# --------------------------------------------------
# 30/202
# Image: inline_skate_0026
# Time taken per label: 20.77 seconds
# --------------------------------------------------
# 31/202
# Image: platypus_0020
# Time taken per label: 19.44 seconds
# --------------------------------------------------
# 32/202
# Image: platypus_0005
# Time taken per label: 23.43 seconds
# --------------------------------------------------
# 33/202
# Image: dalmatian_0058
# Time taken per label: 24.61 seconds
# --------------------------------------------------
# 34/202
# Image: dalmatian_0018
# Time taken per label: 21.91 seconds
# --------------------------------------------------
# 35/202
# Image: cup_0047
# Time taken per label: 25.61 seconds
# --------------------------------------------------
# 36/202
# Image: cup_0029
# Time taken per label: 22.32 seconds
# --------------------------------------------------
# 37/202
# Image: airplanes_0011
# Time taken per label: 25.49 seconds
# --------------------------------------------------
# 38/202
# Image: airplanes_0463
# Time taken per label: 19.34 seconds
# --------------------------------------------------
# 39/202
# Image: joshua_tree_0037
# Time taken per label: 19.45 seconds
# --------------------------------------------------
# 40/202
# Image: joshua_tree_0061
# Time taken per label: 19.46 seconds
# --------------------------------------------------
# 41/202
# Image: cougar_body_0033
# Time taken per label: 22.25 seconds
# --------------------------------------------------
# 42/202
# Image: cougar_body_0009
# Time taken per label: 25.79 seconds
# --------------------------------------------------
# 43/202
# Image: grand_piano_0080
# Time taken per label: 30.5 seconds
# --------------------------------------------------
# 44/202
# Image: grand_piano_0039
# Time taken per label: 33.49 seconds
# --------------------------------------------------
# 45/202
# Image: trilobite_0008
# Time taken per label: 29.21 seconds
# --------------------------------------------------
# 46/202
# Image: trilobite_0030
# Time taken per label: 20.77 seconds
# --------------------------------------------------
# 47/202
# Image: brontosaurus_0041
# Time taken per label: 20.92 seconds
# --------------------------------------------------
# 48/202
# Image: brontosaurus_0034
# Time taken per label: 39.16 seconds
# --------------------------------------------------
# 49/202
# Image: wild_cat_0025
# Time taken per label: 19.48 seconds
# --------------------------------------------------
# 50/202
# Image: wild_cat_0003
# Time taken per label: 20.1 seconds
# --------------------------------------------------
# 51/202
# Image: pigeon_0028
# Time taken per label: 19.83 seconds
# --------------------------------------------------
# 52/202
# Image: pigeon_0010
# Time taken per label: 19.85 seconds
# --------------------------------------------------
# 53/202
# Image: dolphin_0045
# Time taken per label: 26.7 seconds
# --------------------------------------------------
# 54/202
# Image: dolphin_0022
# Time taken per label: 20.24 seconds
# --------------------------------------------------
# 55/202
# Image: soccer_ball_0047
# Time taken per label: 21.08 seconds
# --------------------------------------------------
# 56/202
# Image: soccer_ball_0048
# Time taken per label: 19.84 seconds
# --------------------------------------------------
# 57/202
# Image: wrench_0024
# Time taken per label: 24.79 seconds
# --------------------------------------------------
# 58/202
# Image: wrench_0022
# Time taken per label: 21.4 seconds
# --------------------------------------------------
# 59/202
# Image: scorpion_0075
# Time taken per label: 24.91 seconds
# --------------------------------------------------
# 60/202
# Image: scorpion_0021
# Time taken per label: 29.67 seconds
# --------------------------------------------------
# 61/202
# Image: flamingo_head_0006
# Time taken per label: 25.6 seconds
# --------------------------------------------------
# 62/202
# Image: flamingo_head_0043
# Time taken per label: 25.02 seconds
# --------------------------------------------------
# 63/202
# Image: nautilus_0022
# Time taken per label: 28.3 seconds
# --------------------------------------------------
# 64/202
# Image: nautilus_0038
# Time taken per label: 26.54 seconds
# --------------------------------------------------
# 65/202
# Image: accordion_0017
# Time taken per label: 30.55 seconds
# --------------------------------------------------
# 66/202
# Image: accordion_0027
# Time taken per label: 20.27 seconds
# --------------------------------------------------
# 67/202
# Image: cougar_face_0056
# Time taken per label: 23.65 seconds
# --------------------------------------------------
# 68/202
# Image: cougar_face_0040
# Time taken per label: 26.84 seconds
# --------------------------------------------------
# 69/202
# Image: pyramid_0022
# Time taken per label: 28.1 seconds
# --------------------------------------------------
# 70/202
# Image: pyramid_0020
# Time taken per label: 31.81 seconds
# --------------------------------------------------
# 71/202
# Image: camera_0025
# Time taken per label: 21.66 seconds
# --------------------------------------------------
# 72/202
# Image: camera_0047
# Time taken per label: 19.58 seconds
# --------------------------------------------------
# 73/202
# Image: barrel_0041
# Time taken per label: 19.55 seconds
# --------------------------------------------------
# 74/202
# Image: barrel_0014
# Time taken per label: 21.26 seconds
# --------------------------------------------------
# 75/202
# Image: schooner_0049
# Time taken per label: 22.05 seconds
# --------------------------------------------------
# 76/202
# Image: schooner_0025
# Time taken per label: 23.78 seconds
# --------------------------------------------------
# 77/202
# Image: cellphone_0012
# Time taken per label: 28.96 seconds
# --------------------------------------------------
# 78/202
# Image: cellphone_0018
# Time taken per label: 24.66 seconds
# --------------------------------------------------
# 79/202
# Image: panda_0031
# Time taken per label: 26.34 seconds
# --------------------------------------------------
# 80/202
# Image: panda_0026
# Time taken per label: 26.1 seconds
# --------------------------------------------------
# 81/202
# Image: revolver_0080
# Time taken per label: 29.11 seconds
# --------------------------------------------------
# 82/202
# Image: revolver_0021
# Time taken per label: 27.52 seconds
# --------------------------------------------------
# 83/202
# Image: lobster_0028
# Time taken per label: 30.66 seconds
# --------------------------------------------------
# 84/202
# Image: lobster_0027
# Time taken per label: 19.52 seconds
# --------------------------------------------------
# 85/202
# Image: menorah_0038
# Time taken per label: 22.0 seconds
# --------------------------------------------------
# 86/202
# Image: menorah_0084
# Time taken per label: 20.26 seconds
# --------------------------------------------------
# 87/202
# Image: lotus_0027
# Time taken per label: 19.78 seconds
# --------------------------------------------------
# 88/202
# Image: lotus_0029
# Time taken per label: 19.04 seconds
# --------------------------------------------------
# 89/202
# Image: stapler_0044
# Time taken per label: 18.73 seconds
# --------------------------------------------------
# 90/202
# Image: stapler_0045
# Time taken per label: 20.07 seconds
# --------------------------------------------------
# 91/202
# Image: crocodile_0045
# Time taken per label: 19.39 seconds
# --------------------------------------------------
# 92/202
# Image: crocodile_0009
# Time taken per label: 20.36 seconds
# --------------------------------------------------
# 93/202
# Image: chair_0003
# Time taken per label: 19.13 seconds
# --------------------------------------------------
# 94/202
# Image: chair_0046
# Time taken per label: 20.39 seconds
# --------------------------------------------------
# 95/202
# Image: helicopter_0061
# Time taken per label: 20.5 seconds
# --------------------------------------------------
# 96/202
# Image: helicopter_0036
# Time taken per label: 19.32 seconds
# --------------------------------------------------
# 97/202
# Image: minaret_0076
# Time taken per label: 19.16 seconds
# --------------------------------------------------
# 98/202
# Image: minaret_0048
# Time taken per label: 132.16 seconds
# --------------------------------------------------
# 99/202
# Image: starfish_0078
# Time taken per label: 19.16 seconds
# --------------------------------------------------
# 100/202
# Image: starfish_0068
# Time taken per label: 20.1 seconds
# --------------------------------------------------
# 101/202
# Image: ceiling_fan_0024
# Time taken per label: 20.11 seconds
# --------------------------------------------------
# 102/202
# Image: ceiling_fan_0020
# Time taken per label: 18.27 seconds
# --------------------------------------------------
# 103/202
# Image: ketch_0092
# Time taken per label: 19.55 seconds
# --------------------------------------------------
# 104/202
# Image: ketch_0097
# Time taken per label: 19.77 seconds
# --------------------------------------------------
# 105/202
# Image: mayfly_0018
# Time taken per label: 19.68 seconds
# --------------------------------------------------
# 106/202
# Image: mayfly_0019
# Time taken per label: 21.19 seconds
# --------------------------------------------------
# 107/202
# Image: wheelchair_0023
# Time taken per label: 20.34 seconds
# --------------------------------------------------
# 108/202
# Image: wheelchair_0017
# Time taken per label: 18.8 seconds
# --------------------------------------------------
# 109/202
# Image: bass_0011
# Time taken per label: 18.56 seconds
# --------------------------------------------------
# 110/202
# Image: bass_0047
# Time taken per label: 19.97 seconds
# --------------------------------------------------
# 111/202
# Image: yin_yang_0021
# Time taken per label: 19.0 seconds
# --------------------------------------------------
# 112/202
# Image: yin_yang_0007
# Time taken per label: 20.71 seconds
# --------------------------------------------------
# 113/202
# Image: crocodile_head_0045
# Time taken per label: 27.71 seconds
# --------------------------------------------------
# 114/202
# Image: crocodile_head_0034
# Time taken per label: 19.89 seconds
# --------------------------------------------------
# 115/202
# Image: saxophone_0036
# Time taken per label: 19.37 seconds
# --------------------------------------------------
# 116/202
# Image: saxophone_0033
# Time taken per label: 19.74 seconds
# --------------------------------------------------
# 117/202
# Image: beaver_0014
# Time taken per label: 19.2 seconds
# --------------------------------------------------
# 118/202
# Image: beaver_0001
# Time taken per label: 18.37 seconds
# --------------------------------------------------
# 119/202
# Image: mandolin_0007
# Time taken per label: 21.54 seconds
# --------------------------------------------------
# 120/202
# Image: mandolin_0013
# Time taken per label: 20.25 seconds
# --------------------------------------------------
# 121/202
# Image: bonsai_0003
# Time taken per label: 19.75 seconds
# --------------------------------------------------
# 122/202
# Image: bonsai_0014
# Time taken per label: 19.89 seconds
# --------------------------------------------------
# 123/202
# Image: Leopards_0063
# Time taken per label: 19.57 seconds
# --------------------------------------------------
# 124/202
# Image: Leopards_0108
# Time taken per label: 18.97 seconds
# --------------------------------------------------
# 125/202
# Image: car_side_0084
# Time taken per label: 18.73 seconds
# --------------------------------------------------
# 126/202
# Image: car_side_0118
# Time taken per label: 23.34 seconds
# --------------------------------------------------
# 127/202
# Image: ibis_0045
# Time taken per label: 22.88 seconds
# --------------------------------------------------
# 128/202
# Image: ibis_0039
# Time taken per label: 20.21 seconds
# --------------------------------------------------
# 129/202
# Image: electric_guitar_0032
# Time taken per label: 18.98 seconds
# --------------------------------------------------
# 130/202
# Image: electric_guitar_0035
# Time taken per label: 19.43 seconds
# --------------------------------------------------
# 131/202
# Image: kangaroo_0031
# Time taken per label: 18.82 seconds
# --------------------------------------------------
# 132/202
# Image: kangaroo_0069
# Time taken per label: 20.52 seconds
# --------------------------------------------------
# 133/202
# Image: stegosaurus_0024
# Time taken per label: 20.36 seconds
# --------------------------------------------------
# 134/202
# Image: stegosaurus_0037
# Time taken per label: 19.43 seconds
# --------------------------------------------------
# 135/202
# Image: ferry_0067
# Time taken per label: 19.06 seconds
# --------------------------------------------------
# 136/202
# Image: ferry_0031
# Time taken per label: 18.79 seconds
# --------------------------------------------------
# 137/202
# Image: snoopy_0032
# Time taken per label: 19.49 seconds
# --------------------------------------------------
# 138/202
# Image: snoopy_0029
# Time taken per label: 19.26 seconds
# --------------------------------------------------
# 139/202
# Image: umbrella_0047
# Time taken per label: 18.41 seconds
# --------------------------------------------------
# 140/202
# Image: umbrella_0039
# Time taken per label: 20.19 seconds
# --------------------------------------------------
# 141/202
# Image: rhino_0048
# Time taken per label: 20.7 seconds
# --------------------------------------------------
# 142/202
# Image: rhino_0042
# Time taken per label: 20.88 seconds
# --------------------------------------------------
# 143/202
# Image: okapi_0013
# Time taken per label: 20.75 seconds
# --------------------------------------------------
# 144/202
# Image: okapi_0010
# Time taken per label: 50.8 seconds
# --------------------------------------------------
# 145/202
# Image: watch_0014
# Time taken per label: 20.86 seconds
# --------------------------------------------------
# 146/202
# Image: watch_0151
# Time taken per label: 20.17 seconds
# --------------------------------------------------
# 147/202
# Image: brain_0082
# Time taken per label: 30.69 seconds
# --------------------------------------------------
# 148/202
# Image: brain_0044
# Time taken per label: 21.71 seconds
# --------------------------------------------------
# 149/202
# Image: gramophone_0028
# Time taken per label: 19.84 seconds
# --------------------------------------------------
# 150/202
# Image: gramophone_0043
# Time taken per label: 24.69 seconds
# --------------------------------------------------
# 151/202
# Image: scissors_0037
# Time taken per label: 21.65 seconds
# --------------------------------------------------
# 152/202
# Image: scissors_0027
# Time taken per label: 18.16 seconds
# --------------------------------------------------
# 153/202
# Image: rooster_0024
# Time taken per label: 19.8 seconds
# --------------------------------------------------
# 154/202
# Image: rooster_0038
# Time taken per label: 18.79 seconds
# --------------------------------------------------
# 155/202
# Image: cannon_0002
# Time taken per label: 19.82 seconds
# --------------------------------------------------
# 156/202
# Image: cannon_0041
# Time taken per label: 25.7 seconds
# --------------------------------------------------
# 157/202
# Image: binocular_0012
# Time taken per label: 22.91 seconds
# --------------------------------------------------
# 158/202
# Image: binocular_0008
# Time taken per label: 20.02 seconds
# --------------------------------------------------
# 159/202
# Image: anchor_0005
# Time taken per label: 18.91 seconds
# --------------------------------------------------
# 160/202
# Image: anchor_0016
# Time taken per label: 19.13 seconds
# --------------------------------------------------
# 161/202
# Image: octopus_0003
# Time taken per label: 19.87 seconds
# --------------------------------------------------
# 162/202
# Image: octopus_0012
# Time taken per label: 20.02 seconds
# --------------------------------------------------
# 163/202
# Image: buddha_0026
# Time taken per label: 20.14 seconds
# --------------------------------------------------
# 164/202
# Image: buddha_0018
# Time taken per label: 20.33 seconds
# --------------------------------------------------
# 165/202
# Image: laptop_0017
# Time taken per label: 20.51 seconds
# --------------------------------------------------
# 166/202
# Image: laptop_0074
# Time taken per label: 18.6 seconds
# --------------------------------------------------
# 167/202
# Image: windsor_chair_0005
# Time taken per label: 19.69 seconds
# --------------------------------------------------
# 168/202
# Image: windsor_chair_0026
# Time taken per label: 20.89 seconds
# --------------------------------------------------
# 169/202
# Image: hedgehog_0053
# Time taken per label: 20.02 seconds
# --------------------------------------------------
# 170/202
# Image: hedgehog_0052
# Time taken per label: 21.26 seconds
# --------------------------------------------------
# 171/202
# Image: pizza_0018
# Time taken per label: 22.58 seconds
# --------------------------------------------------
# 172/202
# Image: pizza_0049
# Time taken per label: 19.7 seconds
# --------------------------------------------------
# 173/202
# Image: euphonium_0024
# Time taken per label: 25.74 seconds
# --------------------------------------------------
# 174/202
# Image: euphonium_0061
# Time taken per label: 36.23 seconds
# --------------------------------------------------
# 175/202
# Image: stop_sign_0019
# Time taken per label: 22.74 seconds
# --------------------------------------------------
# 176/202
# Image: stop_sign_0059
# Time taken per label: 19.68 seconds
# --------------------------------------------------
# 177/202
# Image: Motorbikes_0494
# Time taken per label: 37.38 seconds
# --------------------------------------------------
# 178/202
# Image: Motorbikes_0677
# Time taken per label: 19.13 seconds
# --------------------------------------------------
# 179/202
# Image: sea_horse_0031
# Time taken per label: 19.62 seconds
# --------------------------------------------------
# 180/202
# Image: sea_horse_0004
# Time taken per label: 18.1 seconds
# --------------------------------------------------
# 181/202
# Image: flamingo_0001
# Time taken per label: 20.35 seconds
# --------------------------------------------------
# 182/202
# Image: flamingo_0052
# Time taken per label: 21.49 seconds
# --------------------------------------------------
# 183/202
# Image: ewer_0031
# Time taken per label: 21.91 seconds
# --------------------------------------------------
# 184/202
# Image: ewer_0045
# Time taken per label: 87.9 seconds
# --------------------------------------------------
# 185/202
# Image: garfield_0009
# Time taken per label: 20.03 seconds
# --------------------------------------------------
# 186/202
# Image: garfield_0007
# Time taken per label: 22.97 seconds
# --------------------------------------------------
# 187/202
# Image: crayfish_0064
# Time taken per label: 21.05 seconds
# --------------------------------------------------
# 188/202
# Image: crayfish_0065
# Time taken per label: 18.62 seconds
# --------------------------------------------------
# 189/202
# Image: Faces_easy_0121
# Time taken per label: 18.32 seconds
# --------------------------------------------------
# 190/202
# Image: Faces_easy_0285
# Time taken per label: 18.85 seconds
# --------------------------------------------------
# 191/202
# Image: Faces_0026
# Time taken per label: 17.78 seconds
# --------------------------------------------------
# 192/202
# Image: Faces_0042
# Time taken per label: 21.09 seconds
# --------------------------------------------------
# 193/202
# Image: sunflower_0039
# Time taken per label: 19.36 seconds
# --------------------------------------------------
# 194/202
# Image: sunflower_0060
# Time taken per label: 21.26 seconds
# --------------------------------------------------
# 195/202
# Image: llama_0063
# Time taken per label: 19.46 seconds
# --------------------------------------------------
# 196/202
# Image: llama_0019
# Time taken per label: 19.04 seconds
# --------------------------------------------------
# 197/202
# Image: elephant_0009
# Time taken per label: 19.0 seconds
# --------------------------------------------------
# 198/202
# Image: elephant_0039
# Time taken per label: 19.51 seconds
# --------------------------------------------------
# 199/202
# Image: tick_0011
# Time taken per label: 19.11 seconds
# --------------------------------------------------
# 200/202
# Image: tick_0029
# Time taken per label: 19.96 seconds
# --------------------------------------------------
# 201/202
# Image: metronome_0031
# Time taken per label: 29.03 seconds
# --------------------------------------------------
# 202/202
# Image: metronome_0009
# Time taken per label: 22.36 seconds
# --------------------------------------------------

# %%
Cal101Features.img_features
# Out:
#           file_name   label_id init_pred  \
# 0      gerenuk_0011    gerenuk   Gerenuk
# 1      gerenuk_0010    gerenuk      None
# 2    hawksbill_0085  hawksbill      None
# 3    hawksbill_0017  hawksbill      None
# 4    headphone_0024  headphone      None
# ..              ...        ...       ...
# 197   elephant_0039   elephant      None
# 198       tick_0011       tick      None
# 199       tick_0029       tick      None
# 200  metronome_0031  metronome      None
# 201  metronome_0009  metronome      None
#
#                                               img_desc
# 0    The main object in the image is a small, brown...
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 197                                               None
# 198                                               None
# 199                                               None
# 200                                               None
# 201                                               None
#
# [202 rows x 4 columns]

# %%
from modules.gen_features import LabelFeatures
caltech_label_working_file = "../data/caltech-101/cotPrompt/llava/label_features.parquet"
Cal101_LabelFeatures = LabelFeatures(caltech_images_path, caltech_class_meta_path, 
                                    caltech_label_working_file, llm_model=Llama)
# Cal101_LabelFeatures.gen_info()

# %%
# Cal101_LabelFeatures.label_features

# %% [markdown]
# ### Encoder

# %%
from modules.prompts import DefaultPrompt
from modules.encoder import FeaturesEncoder

model = "../models/clip-vit-large-patch14"
caltech_images_path = '../database/Caltech/caltech-101/101_ObjectCategories'

caltech_image_working_file = "../data/caltech-101/cotPrompt/llava/image_features.parquet"
caltech_label_working_file = "../data/caltech-101/cotPrompt/llava/label_features.parquet"

encoding_images_path = "../data/caltech-101/cotPrompt/llava/image_features.pkl"
encoding_labels_path = "../data/caltech-101/cotPrompt/llava/label_features.pkl"

FE = FeaturesEncoder(caltech_images_path, encoding_images_path, encoding_labels_path, 
                     img_file_type='jpg', model=model)

DefPrompt = DefaultPrompt('Default')

human_design_prompt = "A photo of {}"

FE.encode_images(caltech_image_working_file)
# FE.encode_labels(caltech_label_working_file, human_design_prompt)
# Out:
# Loading model: clip-vit-large-patch14
# Creating embedding dict...
# 1/202
# Time taken per label: 7.03 seconds
# --------------------------------------------------
# 2/202
# Time taken per label: 0.53 seconds
# --------------------------------------------------
# 3/202
# Time taken per label: 0.48 seconds
# --------------------------------------------------
# 4/202
# Time taken per label: 0.48 seconds
# --------------------------------------------------
# 5/202
# Time taken per label: 0.46 seconds
# --------------------------------------------------
# 6/202
# Time taken per label: 0.46 seconds
# --------------------------------------------------
# 7/202
# Time taken per label: 0.46 seconds
# --------------------------------------------------
# 8/202
# Time taken per label: 0.44 seconds
# --------------------------------------------------
# 9/202
# Time taken per label: 0.49 seconds
# --------------------------------------------------
# 10/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 11/202
# Time taken per label: 0.49 seconds
# --------------------------------------------------
# 12/202
# Time taken per label: 0.74 seconds
# --------------------------------------------------
# 13/202
# Time taken per label: 0.6 seconds
# --------------------------------------------------
# 14/202
# Time taken per label: 0.7 seconds
# --------------------------------------------------
# 15/202
# Time taken per label: 0.96 seconds
# --------------------------------------------------
# 16/202
# Time taken per label: 0.72 seconds
# --------------------------------------------------
# 17/202
# Time taken per label: 0.58 seconds
# --------------------------------------------------
# 18/202
# Time taken per label: 1.3 seconds
# --------------------------------------------------
# 19/202
# Time taken per label: 0.87 seconds
# --------------------------------------------------
# 20/202
# Time taken per label: 0.59 seconds
# --------------------------------------------------
# 21/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 22/202
# Time taken per label: 0.57 seconds
# --------------------------------------------------
# 23/202
# Time taken per label: 0.48 seconds
# --------------------------------------------------
# 24/202
# Time taken per label: 0.47 seconds
# --------------------------------------------------
# 25/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 26/202
# Time taken per label: 0.51 seconds
# --------------------------------------------------
# 27/202
# Time taken per label: 0.53 seconds
# --------------------------------------------------
# 28/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 29/202
# Time taken per label: 0.54 seconds
# --------------------------------------------------
# 30/202
# Time taken per label: 0.49 seconds
# --------------------------------------------------
# 31/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 32/202
# Time taken per label: 0.53 seconds
# --------------------------------------------------
# 33/202
# Time taken per label: 0.57 seconds
# --------------------------------------------------
# 34/202
# Time taken per label: 0.57 seconds
# --------------------------------------------------
# 35/202
# Time taken per label: 0.49 seconds
# --------------------------------------------------
# 36/202
# Time taken per label: 0.47 seconds
# --------------------------------------------------
# 37/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 38/202
# Time taken per label: 0.53 seconds
# --------------------------------------------------
# 39/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 40/202
# Time taken per label: 0.46 seconds
# --------------------------------------------------
# 41/202
# Time taken per label: 0.54 seconds
# --------------------------------------------------
# 42/202
# Time taken per label: 0.51 seconds
# --------------------------------------------------
# 43/202
# Time taken per label: 0.48 seconds
# --------------------------------------------------
# 44/202
# Time taken per label: 0.47 seconds
# --------------------------------------------------
# 45/202
# Time taken per label: 0.53 seconds
# --------------------------------------------------
# 46/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 47/202
# Time taken per label: 0.47 seconds
# --------------------------------------------------
# 48/202
# Time taken per label: 0.45 seconds
# --------------------------------------------------
# 49/202
# Time taken per label: 0.48 seconds
# --------------------------------------------------
# 50/202
# Time taken per label: 0.47 seconds
# --------------------------------------------------
# 51/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 52/202
# Time taken per label: 0.59 seconds
# --------------------------------------------------
# 53/202
# Time taken per label: 0.54 seconds
# --------------------------------------------------
# 54/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 55/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 56/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 57/202
# Time taken per label: 0.48 seconds
# --------------------------------------------------
# 58/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 59/202
# Time taken per label: 0.67 seconds
# --------------------------------------------------
# 60/202
# Time taken per label: 1.23 seconds
# --------------------------------------------------
# 61/202
# Time taken per label: 0.7 seconds
# --------------------------------------------------
# 62/202
# Time taken per label: 1.08 seconds
# --------------------------------------------------
# 63/202
# Time taken per label: 0.89 seconds
# --------------------------------------------------
# 64/202
# Time taken per label: 0.88 seconds
# --------------------------------------------------
# 65/202
# Time taken per label: 0.91 seconds
# --------------------------------------------------
# 66/202
# Time taken per label: 0.94 seconds
# --------------------------------------------------
# 67/202
# Time taken per label: 0.73 seconds
# --------------------------------------------------
# 68/202
# Time taken per label: 0.66 seconds
# --------------------------------------------------
# 69/202
# Time taken per label: 0.96 seconds
# --------------------------------------------------
# 70/202
# Time taken per label: 0.84 seconds
# --------------------------------------------------
# 71/202
# Time taken per label: 0.71 seconds
# --------------------------------------------------
# 72/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 73/202
# Time taken per label: 0.62 seconds
# --------------------------------------------------
# 74/202
# Time taken per label: 0.68 seconds
# --------------------------------------------------
# 75/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 76/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 77/202
# Time taken per label: 0.68 seconds
# --------------------------------------------------
# 78/202
# Time taken per label: 0.93 seconds
# --------------------------------------------------
# 79/202
# Time taken per label: 0.54 seconds
# --------------------------------------------------
# 80/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 81/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 82/202
# Time taken per label: 0.53 seconds
# --------------------------------------------------
# 83/202
# Time taken per label: 0.61 seconds
# --------------------------------------------------
# 84/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 85/202
# Time taken per label: 0.63 seconds
# --------------------------------------------------
# 86/202
# Time taken per label: 0.64 seconds
# --------------------------------------------------
# 87/202
# Time taken per label: 0.65 seconds
# --------------------------------------------------
# 88/202
# Time taken per label: 0.69 seconds
# --------------------------------------------------
# 89/202
# Time taken per label: 0.58 seconds
# --------------------------------------------------
# 90/202
# Time taken per label: 0.62 seconds
# --------------------------------------------------
# 91/202
# Time taken per label: 0.51 seconds
# --------------------------------------------------
# 92/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 93/202
# Time taken per label: 0.58 seconds
# --------------------------------------------------
# 94/202
# Time taken per label: 0.62 seconds
# --------------------------------------------------
# 95/202
# Time taken per label: 0.61 seconds
# --------------------------------------------------
# 96/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 97/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 98/202
# Time taken per label: 0.54 seconds
# --------------------------------------------------
# 99/202
# Time taken per label: 0.51 seconds
# --------------------------------------------------
# 100/202
# Time taken per label: 0.59 seconds
# --------------------------------------------------
# 101/202
# Time taken per label: 0.67 seconds
# --------------------------------------------------
# 102/202
# Time taken per label: 0.66 seconds
# --------------------------------------------------
# 103/202
# Time taken per label: 0.51 seconds
# --------------------------------------------------
# 104/202
# Time taken per label: 0.54 seconds
# --------------------------------------------------
# 105/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 106/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 107/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 108/202
# Time taken per label: 0.69 seconds
# --------------------------------------------------
# 109/202
# Time taken per label: 0.51 seconds
# --------------------------------------------------
# 110/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 111/202
# Time taken per label: 0.65 seconds
# --------------------------------------------------
# 112/202
# Time taken per label: 1.11 seconds
# --------------------------------------------------
# 113/202
# Time taken per label: 1.19 seconds
# --------------------------------------------------
# 114/202
# Time taken per label: 1.13 seconds
# --------------------------------------------------
# 115/202
# Time taken per label: 0.83 seconds
# --------------------------------------------------
# 116/202
# Time taken per label: 0.97 seconds
# --------------------------------------------------
# 117/202
# Time taken per label: 0.67 seconds
# --------------------------------------------------
# 118/202
# Time taken per label: 1.12 seconds
# --------------------------------------------------
# 119/202
# Time taken per label: 0.96 seconds
# --------------------------------------------------
# 120/202
# Time taken per label: 0.86 seconds
# --------------------------------------------------
# 121/202
# Time taken per label: 0.91 seconds
# --------------------------------------------------
# 122/202
# Time taken per label: 0.87 seconds
# --------------------------------------------------
# 123/202
# Time taken per label: 0.61 seconds
# --------------------------------------------------
# 124/202
# Time taken per label: 0.65 seconds
# --------------------------------------------------
# 125/202
# Time taken per label: 0.66 seconds
# --------------------------------------------------
# 126/202
# Time taken per label: 0.61 seconds
# --------------------------------------------------
# 127/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 128/202
# Time taken per label: 0.52 seconds
# --------------------------------------------------
# 129/202
# Time taken per label: 0.51 seconds
# --------------------------------------------------
# 130/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 131/202
# Time taken per label: 0.63 seconds
# --------------------------------------------------
# 132/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 133/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 134/202
# Time taken per label: 0.58 seconds
# --------------------------------------------------
# 135/202
# Time taken per label: 0.57 seconds
# --------------------------------------------------
# 136/202
# Time taken per label: 0.68 seconds
# --------------------------------------------------
# 137/202
# Time taken per label: 0.72 seconds
# --------------------------------------------------
# 138/202
# Time taken per label: 0.92 seconds
# --------------------------------------------------
# 139/202
# Time taken per label: 0.72 seconds
# --------------------------------------------------
# 140/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 141/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 142/202
# Time taken per label: 0.81 seconds
# --------------------------------------------------
# 143/202
# Time taken per label: 0.66 seconds
# --------------------------------------------------
# 144/202
# Time taken per label: 0.58 seconds
# --------------------------------------------------
# 145/202
# Time taken per label: 0.57 seconds
# --------------------------------------------------
# 146/202
# Time taken per label: 0.57 seconds
# --------------------------------------------------
# 147/202
# Time taken per label: 0.55 seconds
# --------------------------------------------------
# 148/202
# Time taken per label: 0.5 seconds
# --------------------------------------------------
# 149/202
# Time taken per label: 0.57 seconds
# --------------------------------------------------
# 150/202
# Time taken per label: 0.85 seconds
# --------------------------------------------------
# 151/202
# Time taken per label: 1.31 seconds
# --------------------------------------------------
# 152/202
# Time taken per label: 0.9 seconds
# --------------------------------------------------
# 153/202
# Time taken per label: 1.08 seconds
# --------------------------------------------------
# 154/202
# Time taken per label: 4.6 seconds
# --------------------------------------------------
# 155/202
# Time taken per label: 3.42 seconds
# --------------------------------------------------
# 156/202
# Time taken per label: 1.75 seconds
# --------------------------------------------------
# 157/202
# Time taken per label: 1.23 seconds
# --------------------------------------------------
# 158/202
# Time taken per label: 0.81 seconds
# --------------------------------------------------
# 159/202
# Time taken per label: 0.71 seconds
# --------------------------------------------------
# 160/202
# Time taken per label: 0.86 seconds
# --------------------------------------------------
# 161/202
# Time taken per label: 0.66 seconds
# --------------------------------------------------
# 162/202
# Time taken per label: 0.71 seconds
# --------------------------------------------------
# 163/202
# Time taken per label: 1.02 seconds
# --------------------------------------------------
# 164/202
# Time taken per label: 0.93 seconds
# --------------------------------------------------
# 165/202
# Time taken per label: 0.88 seconds
# --------------------------------------------------
# 166/202
# Time taken per label: 0.94 seconds
# --------------------------------------------------
# 167/202
# Time taken per label: 0.96 seconds
# --------------------------------------------------
# 168/202
# Time taken per label: 0.79 seconds
# --------------------------------------------------
# 169/202
# Time taken per label: 0.96 seconds
# --------------------------------------------------
# 170/202
# Time taken per label: 0.67 seconds
# --------------------------------------------------
# 171/202
# Time taken per label: 0.94 seconds
# --------------------------------------------------
# 172/202
# Time taken per label: 0.87 seconds
# --------------------------------------------------
# 173/202
# Time taken per label: 0.68 seconds
# --------------------------------------------------
# 174/202
# Time taken per label: 1.02 seconds
# --------------------------------------------------
# 175/202
# Time taken per label: 0.86 seconds
# --------------------------------------------------
# 176/202
# Time taken per label: 0.63 seconds
# --------------------------------------------------
# 177/202
# Time taken per label: 0.54 seconds
# --------------------------------------------------
# 178/202
# Time taken per label: 0.53 seconds
# --------------------------------------------------
# 179/202
# Time taken per label: 0.69 seconds
# --------------------------------------------------
# 180/202
# Time taken per label: 0.71 seconds
# --------------------------------------------------
# 181/202
# Time taken per label: 1.0 seconds
# --------------------------------------------------
# 182/202
# Time taken per label: 1.29 seconds
# --------------------------------------------------
# 183/202
# Time taken per label: 1.47 seconds
# --------------------------------------------------
# 184/202
# Time taken per label: 1.72 seconds
# --------------------------------------------------
# 185/202
# Time taken per label: 1.76 seconds
# --------------------------------------------------
# 186/202
# Time taken per label: 0.73 seconds
# --------------------------------------------------
# 187/202
# Time taken per label: 0.66 seconds
# --------------------------------------------------
# 188/202
# Time taken per label: 0.99 seconds
# --------------------------------------------------
# 189/202
# Time taken per label: 0.92 seconds
# --------------------------------------------------
# 190/202
# Time taken per label: 0.75 seconds
# --------------------------------------------------
# 191/202
# Time taken per label: 0.78 seconds
# --------------------------------------------------
# 192/202
# Time taken per label: 0.63 seconds
# --------------------------------------------------
# 193/202
# Time taken per label: 0.6 seconds
# --------------------------------------------------
# 194/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 195/202
# Time taken per label: 0.84 seconds
# --------------------------------------------------
# 196/202
# Time taken per label: 0.74 seconds
# --------------------------------------------------
# 197/202
# Time taken per label: 0.89 seconds
# --------------------------------------------------
# 198/202
# Time taken per label: 1.03 seconds
# --------------------------------------------------
# 199/202
# Time taken per label: 0.56 seconds
# --------------------------------------------------
# 200/202
# Time taken per label: 0.59 seconds
# --------------------------------------------------
# 201/202
# Time taken per label: 0.89 seconds
# --------------------------------------------------
# 202/202
# Time taken per label: 0.8 seconds
# --------------------------------------------------

# %%
FE.encode_labels(caltech_label_working_file, human_design_prompt)

# %% [markdown]
# ### Prediction

# %%
import pickle
from modules.classifier import ImageClassifier
# Classification
encoded_image_file = "../data/caltech-101/cotPrompt/llava/image_features.pkl"
encoded_text_file  = "../data/caltech-101/cotPrompt/llava/label_features.pkl"

with open(encoded_image_file, "rb") as f: 
    img_features = pickle.load(f)

with open(encoded_text_file, "rb") as f: 
    label_features = pickle.load(f)

# %%
import pandas as pd
acc_df = pd.DataFrame(columns=['accuracy', 'precision', 'recall', 'f1'])
for X in ['X_if', 'X_df', 'X_pf', 'X_q']:
    I4P = ImageClassifier(label_features, mode='M4', img_features=img_features, ifeature=X)
    print("="*50)
    df = I4P.classify()
    accuracy, precision, recall, f1 = I4P.evaluation(df)
    acc_df.loc[X] = [accuracy, precision, recall, f1]

save_path = "../data/accuracies/caltech_llava_cot.csv"
acc_df.to_csv(save_path, index=False)
acc_df.head()
# Out:
# Using model M4: Fused Features Embedding
# Using Image Feature: Encoded Image X_if
# ==================================================
# Accuracy: 0.9208
# Precision: 0.9208
# Recall: 0.9125
# F1-score: 0.9073
# Using model M4: Fused Features Embedding
# Using Image Feature: Encoded Image Description X_df
# ==================================================
# Accuracy: 0.6832
# Precision: 0.6832
# Recall: 0.6335
# F1-score: 0.6303
# Using model M4: Fused Features Embedding
# Using Image Feature: Encoded Init Prediction X_pf
# ==================================================
# Accuracy: 0.7178
# Precision: 0.7178
# Recall: 0.6541
# F1-score: 0.6615
# Using model M4: Fused Features Embedding
# Using Image Feature: Encoded Fused Image Feature X_q
# ==================================================
# Accuracy: 0.7525
# Precision: 0.7525
# Recall: 0.7078
# F1-score: 0.7042
#       accuracy  precision    recall        f1
# X_if  0.920792   0.920792  0.912541  0.907261
# X_df  0.683168   0.683168  0.633534  0.630344
# X_pf  0.717822   0.717822  0.654125  0.661528
# X_q   0.752475   0.752475  0.707779  0.704212
